# %% [markdown]
# <a href="https://colab.research.google.com/github/RicLupi03/Project_Cognition_Computation/blob/main/Project_Cog_Comp_(12).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project of Cognition and Computation - Lupi Riccardo 2205445

# %% [markdown]
# ##Introduction

# %% [markdown]
# ### Setup of the Project
# As first step we download two simple scripts implementing a Deep Belief Network in PyTorch and import a few useful Python libraries.

# %%
def get_dbn_library():
  files = ["DBN.py", "RBM.py"]
  repository_url = "https://raw.githubusercontent.com/flavio2018/Deep-Belief-Network-pytorch/master/"
  for file in files:
    ! wget -O {file} {repository_url}{file}

# %%
# %%capture
get_dbn_library()

# %%
import matplotlib.pyplot as plt
import torch
import math
import scipy.cluster as cluster
import torch.nn.functional as functional
import numpy as np
import seaborn as sns
import torchvision as tv
from tqdm.notebook import tqdm
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import sklearn.preprocessing

from DBN import DBN

# %% [markdown]
# Then we select the kind of hardware device that is going to be used for computations (CPU or GPU).

# %%
print(torch.cuda.is_available())
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# True
# cuda

# %% [markdown]
# ## Dataset: Fashion-MNIST
#
# 60k train/10k test 28x28 grayscale images (10 clothing classes: T-shirt to Ankle boot). Normalized [0,1], GPU-ready. Chosen over MNIST for semantic variety (project req: beyond digits).

# %%
# Project datasets Fashion-MNIST
fashion_tr = tv.datasets.FashionMNIST(root='./mnist', train=True, download=True)
fashion_te = tv.datasets.FashionMNIST(root='./mnist', train=False, download=True)

fashion_tr.data = fashion_tr.data / 255
fashion_te.data = fashion_te.data / 255

fashion_tr.data = fashion_tr.data.to(device)
fashion_te.data = fashion_te.data.to(device)

fashion_tr.targets = fashion_tr.targets.to(device)
fashion_te.targets = fashion_te.targets.to(device)

print(f"Fashion-MNIST - Train: {fashion_tr.data.shape}, Test: {fashion_te.data.shape}")
print("Classes: 0=T-shirt/top, 1=Trouser, 2=Pullover, 3=Dress, 4=Coat, 5=Sandal, 6=Shirt, 7=Sneaker, 8=Bag, 9=Ankle boot")
# Out:
# 100%|██████████| 26.4M/26.4M [00:00<00:00, 107MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 3.83MB/s]
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 55.7MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 31.4MB/s]
# Fashion-MNIST - Train: torch.Size([60000, 28, 28]), Test: torch.Size([10000, 28, 28])
# Classes: 0=T-shirt/top, 1=Trouser, 2=Pullover, 3=Dress, 4=Coat, 5=Sandal, 6=Shirt, 7=Sneaker, 8=Bag, 9=Ankle boot

# %% [markdown]
# Let's visualize one training image:

# %%
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

idx = 0
img = fashion_tr.data[idx].cpu()  # NB: to plot the data, we need to move it back from the GPU memory!
print("The image shows the clothing: ", class_names[(fashion_tr.targets[idx])])
plt.imshow(img , cmap = 'gray')
plt.show()
# Out:
# The image shows the clothing:  Ankle boot

# %% [markdown]
# Following are the distribution of the classes on the test and training set

# %%
classes = list(range(10))
# Move to CPU
fashion_targets_train = fashion_tr.targets.cpu().numpy()
fashion_targets_test  = fashion_te.targets.cpu().numpy()

x = np.arange(10)
width = 0.35

train_perc = [int(np.sum(fashion_targets_train == i) / len(fashion_targets_train) * 100) for i in classes]
test_perc  = [int(np.sum(fashion_targets_test == i) / len(fashion_targets_test) * 100) for i in classes]

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, train_perc, width, label='Train')
rects2 = ax.bar(x + width/2, test_perc, width, label='Test')

ax.set_ylabel('Percentage')
ax.set_xlabel('Class index')
ax.set_title('Fashion-MNIST label distribution')
ax.legend()

plt.xticks(classes, class_names, rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see from the graph, Fashion-MNIST has perfectly balanced class distribution.

# %% [markdown]
# ## DBN Architecture & Training
#
# 3-layer stack of RBMs: visible=784 (flattened 28x28), hidden=[500,600,1000] (tuned larger vs. labs for better Fashion-MNIST reps). Unsupervised max-likelihood via contrastive divergence (k=1). 50 epochs monitor rec error.

# %%
dbn_fashion = DBN(visible_units=28*28,
                hidden_units=[500, 600, 1000],
                k=1,
                learning_rate=0.1,
                learning_rate_decay=False,
                initial_momentum=0.5,
                final_momentum=0.95,
                weight_decay=0.0001,
                xavier_init=False,
                increase_to_cd_k=False,
                use_gpu=torch.cuda.is_available())

# %% [markdown]
# Now we train the model

# %%
num_epochs = 50
batch_size = 125

dbn_fashion.train_static(
    fashion_tr.data,
    fashion_tr.targets,
    num_epochs,
    batch_size
)
# Out:
# --------------------
# Training RBM layer 1
# |Epoch |avg_rec_err |std_rec_err  |mean_grad |std_grad  |
# |10    |1.8285     |0.0815       |336.1055   |6.9860     |
# |20    |1.7132     |0.0777       |320.5957   |5.3503     |
# |30    |1.6815     |0.0769       |319.0772   |5.8329     |
# |40    |1.6669     |0.0747       |317.1005   |5.4775     |
# |50    |1.6559     |0.0740       |311.3884   |5.6478     |
# --------------------
# Training RBM layer 2
# |Epoch |avg_rec_err |std_rec_err  |mean_grad |std_grad  |
# |10    |0.9109     |0.0304       |165.1622   |2.7767     |
# |20    |0.8399     |0.0297       |154.8886   |2.6257     |
# |30    |0.8206     |0.0287       |150.4742   |2.3500     |
# |40    |0.8138     |0.0267       |149.6990   |2.3020     |
# |50    |0.8093     |0.0268       |147.8157   |2.4294     |
# --------------------
# Training RBM layer 3
# |Epoch |avg_rec_err |std_rec_err  |mean_grad |std_grad  |
# |10    |0.7394     |0.0255       |171.1302   |2.6208     |
# |20    |0.6540     |0.0203       |155.8180   |2.5217     |
# |30    |0.6290     |0.0209       |153.8652   |2.1437     |
# |40    |0.6183     |0.0208       |156.1047   |2.8369     |
# |50    |0.6113     |0.0200       |155.1301   |2.3267     |

# %% [markdown]
# ## Visualizing receptive fields

# %%
def get_weights(dbn, layer):
  return dbn.rbm_layers[layer].W.cpu().numpy()

def apply_threshold(weights, threshold=0):
  return weights * (abs(weights) > threshold)

def apply_min_max_scaler(learned_weights):
  original_shape = learned_weights.shape
  min_max_scaler = sklearn.preprocessing.MinMaxScaler()
  min_max_scaled_learned_weights = min_max_scaler.fit_transform(learned_weights.ravel().reshape(-1,1))
  min_max_scaled_learned_weights = min_max_scaled_learned_weights.reshape(original_shape)
  return min_max_scaled_learned_weights

def plot_layer_receptive_fields(weights):
  num_subplots = 100
  n_rows_cols = int(math.sqrt(num_subplots))
  fig, axes = plt.subplots(n_rows_cols, n_rows_cols, sharex=True, sharey=True, figsize=(10, 10))
  for i in range(num_subplots):
    row = i % n_rows_cols
    col = i // n_rows_cols
    axes[row, col].imshow(weights[i,:].reshape((28,28)), cmap=plt.cm.gray)  # here we select the weights we want to plot

# %% [markdown]
# ## Layer 1 Receptive Fields
#
# Extract W (784x500), threshold >0.1, min-max scale [0,1]. Plot first 100 as 28x28 images: expect edges/textures tuned to clothing patterns (e.g., lines for trousers).

# %%
#first layer visualization
w1 = get_weights(dbn_fashion, layer=0)
w1 = apply_threshold(w1, 0.1)
w1 = apply_min_max_scaler(w1)

plot_layer_receptive_fields(w1.T)

# %% [markdown]
# ## Layers 2-3 Receptive Fields
#
# Repeat for deeper RBMs: expect more abstract/complex patterns (e.g., garment shapes in L3). Threshold reveals sparse, interpretable features.

# %%
#second layer
w1 = get_weights(dbn_fashion, layer=0)
w2 = get_weights(dbn_fashion, layer=1)

w1 = apply_threshold(w1, 0.1)
w2 = apply_threshold(w2, 0.1)

w_product = (w1 @ w2)  # here we do the projection
w_product = apply_threshold(w_product, 0.1)
w_product = apply_min_max_scaler(w_product)

plot_layer_receptive_fields(w_product.T)

# %%
#third layer
w1 = get_weights(dbn_fashion, layer=0)
w2 = get_weights(dbn_fashion, layer=1)
w3 = get_weights(dbn_fashion, layer=2)

w1 = apply_threshold(w1, 0.1)
w2 = apply_threshold(w2, 0.1)
w3 = apply_threshold(w3, 0.1)

w_product_12 = (w1 @ w2)  # here we do the projection
w_product_23 = (w_product_12 @ w3)  # here we do the projection
w_product_23 = apply_threshold(w_product_23, 0.1)
w_product_23 = apply_min_max_scaler(w_product_23)

plot_layer_receptive_fields(w_product_23.T)

# %% [markdown]
# ## Hidden Representation Extraction
#
# Bottom-up forward pass: raw pixels → L1 reps → L2 → L3. Chained for hierarchy (input to next RBM).

# %%
def get_kth_layer_repr(input, k, device):
  flattened_input = input.view((input.shape[0], -1)).type(torch.FloatTensor).to(device)
  hidden_repr, __ = dbn_fashion.rbm_layers[k].to_hidden(flattened_input)  # here we access the RBM object
  return hidden_repr

# %% [markdown]
# ## Extract Train Reps
#
# Compute activations for all 60k train images at 3 levels (shapes: 60k x hidden_units).

# %%
hidden_repr_1 = get_kth_layer_repr(fashion_tr.data, 0, device)
hidden_repr_2 = get_kth_layer_repr(hidden_repr_1, 1, device)
hidden_repr_3 = get_kth_layer_repr(hidden_repr_2, 2, device)
print(hidden_repr_1.shape)
print(hidden_repr_2.shape)
print(hidden_repr_3.shape)
# Out:
# torch.Size([60000, 500])
# torch.Size([60000, 600])
# torch.Size([60000, 1000])

# %% [markdown]
# ## Class Prototypes (for Clustering)
#
# Per-class mean hidden reps (centroids): filter by label, average → 10xD matrix for dendrogram/PCA later

# %%
def get_mask(label):  # we use this function to filter by class
  labels = fashion_tr.targets.cpu().numpy()
  return labels == label

def get_label_to_mean_hidd_repr(hidden_repr):
  hidden_repr_np = hidden_repr.cpu().numpy()
  return {
    label: hidden_repr_np[get_mask(label)].mean(axis=0)  # here we filter by class and compute the mean
    for label in range(10)
  }

def get_hidden_reprs_matrix(hidden_repr):  # we use this to build the matrices
  label_to_mean_hidd_repr = get_label_to_mean_hidd_repr(hidden_repr)
  return np.concatenate(
    [np.expand_dims(label_to_mean_hidd_repr[label], axis=0)  # here we adjust the shape of centroids to do the concat
    for label in range(10)])

# %%
mean_hidd_repr_matrix_3 = get_hidden_reprs_matrix(hidden_repr_3)

# %%
def plot_dendrogram(mean_repr_matrix, title=""):
  fig, ax = plt.subplots()
  linkage = cluster.hierarchy.linkage(mean_repr_matrix, method="complete")  # we run the clustering algorithm here
  dendrogram = cluster.hierarchy.dendrogram(linkage)
  ax.set_title(title)

# %% [markdown]
# Now we can run the clustering algorithm and visualize it output in a dendrogram plot.

# %%
plot_dendrogram(mean_hidd_repr_matrix_3, "Third hidden layer")

# %% [markdown]
# # AutoEncoder Section (to refine)

# %%
import keras
from keras import layers
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
encoding_dim = 32  # 32 floats -> compression of factor 24.5 with input 784 floats

input_img = keras.Input(shape=(784,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
es = EarlyStopping(monitor='val_loss',
                        mode='min',
                        patience = 8,
                        verbose=1)

def train_autoencoder_one_layer():
  data_trans = np.reshape(fashion_tr.data.cpu().numpy(), (len(fashion_tr.data.cpu().numpy()), 784))
  autoencoder.fit(data_trans, data_trans, epochs=500, batch_size=16, verbose=1, validation_split=0.25, callbacks=[es])
  return autoencoder

# %%
autoencoder = train_autoencoder_one_layer()
# Out:
# Epoch 1/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.3642 - val_loss: 0.2943
# Epoch 2/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2895 - val_loss: 0.2870
# Epoch 3/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2853 - val_loss: 0.2855
# Epoch 4/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2848 - val_loss: 0.2847
# Epoch 5/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2834 - val_loss: 0.2844
# Epoch 6/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2831 - val_loss: 0.2839
# Epoch 7/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2824 - val_loss: 0.2838
# Epoch 8/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2818 - val_loss: 0.2835
# Epoch 9/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2828 - val_loss: 0.2834
# Epoch 10/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2824 - val_loss: 0.2835
# Epoch 11/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2821 - val_loss: 0.2836
# Epoch 12/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2820 - val_loss: 0.2836
# Epoch 13/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2817 - val_loss: 0.2834
# Epoch 14/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2815 - val_loss: 0.2833
# Epoch 15/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2824 - val_loss: 0.2831
# Epoch 16/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2818 - val_loss: 0.2834
# Epoch 17/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2819 - val_loss: 0.2833
# Epoch 18/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2815 - val_loss: 0.2830
# Epoch 19/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2817 - val_loss: 0.2833
# Epoch 20/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2821 - val_loss: 0.2831
# Epoch 21/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2814 - val_loss: 0.2831
# Epoch 22/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2817 - val_loss: 0.2831
# Epoch 23/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2820 - val_loss: 0.2832
# Epoch 24/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2816 - val_loss: 0.2829
# Epoch 25/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2822 - val_loss: 0.2831
# Epoch 26/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2821 - val_loss: 0.2830
# Epoch 27/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2813 - val_loss: 0.2830
# Epoch 28/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2813 - val_loss: 0.2834
# Epoch 29/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2812 - val_loss: 0.2830
# Epoch 30/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2819 - val_loss: 0.2830
# Epoch 31/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2813 - val_loss: 0.2829
# Epoch 32/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2812 - val_loss: 0.2827
# Epoch 33/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2810 - val_loss: 0.2827
# Epoch 34/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2814 - val_loss: 0.2828
# Epoch 35/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2818 - val_loss: 0.2828
# Epoch 36/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2818 - val_loss: 0.2827
# Epoch 37/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2814 - val_loss: 0.2830
# Epoch 38/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2816 - val_loss: 0.2829
# Epoch 39/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2811 - val_loss: 0.2828
# Epoch 40/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.2811 - val_loss: 0.2827
# Epoch 40: early stopping

# %%
# Complex AE (80→32→80→784)
input_layer_complex = keras.Input(shape=(784,))
x = layers.Dense(80, activation='relu')(input_layer_complex)
x = layers.Dense(32, activation='relu')(x)  # Bottleneck
x = layers.Dense(80, activation='relu')(x)
output_layer_complex = layers.Dense(784, activation='sigmoid')(x)
autoencoder_complex = keras.Model(inputs=input_layer_complex, outputs=output_layer_complex)

autoencoder_complex.compile(optimizer='adam', loss='binary_crossentropy')
data_trans = np.reshape(fashion_tr.data.cpu().numpy(), (len(fashion_tr.data.cpu().numpy()), 784))
# Corrected: Do not reassign autoencoder_complex with the History object
autoencoder_complex.fit(data_trans, data_trans, epochs=500, batch_size=16, verbose=1, validation_split=0.25, callbacks=[es])
# Out:
# Epoch 1/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.3524 - val_loss: 0.2957
# Epoch 2/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2927 - val_loss: 0.2883
# Epoch 3/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2853 - val_loss: 0.2842
# Epoch 4/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2823 - val_loss: 0.2820
# Epoch 5/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2808 - val_loss: 0.2815
# Epoch 6/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2800 - val_loss: 0.2801
# Epoch 7/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2781 - val_loss: 0.2789
# Epoch 8/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2773 - val_loss: 0.2786
# Epoch 9/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2766 - val_loss: 0.2781
# Epoch 10/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2760 - val_loss: 0.2779
# Epoch 11/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2761 - val_loss: 0.2771
# Epoch 12/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2759 - val_loss: 0.2773
# Epoch 13/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2757 - val_loss: 0.2767
# Epoch 14/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2754 - val_loss: 0.2763
# Epoch 15/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2753 - val_loss: 0.2765
# Epoch 16/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2754 - val_loss: 0.2764
# Epoch 17/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2749 - val_loss: 0.2764
# Epoch 18/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2739 - val_loss: 0.2759
# Epoch 19/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2739 - val_loss: 0.2757
# Epoch 20/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2737 - val_loss: 0.2755
# Epoch 21/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2731 - val_loss: 0.2753
# Epoch 22/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2741 - val_loss: 0.2751
# Epoch 23/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2736 - val_loss: 0.2752
# Epoch 24/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2745 - val_loss: 0.2752
# Epoch 25/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2729 - val_loss: 0.2753
# Epoch 26/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2735 - val_loss: 0.2752
# Epoch 27/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2735 - val_loss: 0.2749
# Epoch 28/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2728 - val_loss: 0.2749
# Epoch 29/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2728 - val_loss: 0.2749
# Epoch 30/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2725 - val_loss: 0.2747
# Epoch 31/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2736 - val_loss: 0.2745
# Epoch 32/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2732 - val_loss: 0.2743
# Epoch 33/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2736 - val_loss: 0.2745
# Epoch 34/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2730 - val_loss: 0.2748
# Epoch 35/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2725 - val_loss: 0.2746
# Epoch 36/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2733 - val_loss: 0.2744
# Epoch 37/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2726 - val_loss: 0.2750
# Epoch 38/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.2732 - val_loss: 0.2744
# Epoch 39/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2725 - val_loss: 0.2742
# Epoch 40/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2730 - val_loss: 0.2747
# Epoch 41/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2737 - val_loss: 0.2745
# Epoch 42/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2731 - val_loss: 0.2743
# Epoch 43/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2723 - val_loss: 0.2742
# Epoch 44/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2722 - val_loss: 0.2743
# Epoch 45/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2735 - val_loss: 0.2738
# Epoch 46/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2724 - val_loss: 0.2746
# Epoch 47/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2733 - val_loss: 0.2741
# Epoch 48/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2732 - val_loss: 0.2739
# Epoch 49/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2721 - val_loss: 0.2739
# Epoch 50/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2738 - val_loss: 0.2741
# Epoch 51/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2728 - val_loss: 0.2741
# Epoch 52/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2718 - val_loss: 0.2736
# Epoch 53/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2722 - val_loss: 0.2741
# Epoch 54/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2727 - val_loss: 0.2739
# Epoch 55/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2718 - val_loss: 0.2737
# Epoch 56/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2726 - val_loss: 0.2738
# Epoch 57/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.2723 - val_loss: 0.2741
# Epoch 58/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2724 - val_loss: 0.2737
# Epoch 59/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2723 - val_loss: 0.2741
# Epoch 60/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2721 - val_loss: 0.2740
# Epoch 60: early stopping

# %% [markdown]
# ## Train a new AE on noised data

# %%
# --- NEW AE (next to autoencoder_complex) ---
import keras
from keras import layers
from keras.callbacks import EarlyStopping
import numpy as np

es = EarlyStopping(monitor="val_loss", mode="min", patience=8, verbose=1)

# Example architecture (edit sizes as you like)
input_layer_new = keras.Input(shape=(784,), name="ae_new_input")
x = layers.Dense(128, activation="relu", name="ae_new_enc1")(input_layer_new)
x = layers.Dense(32,  activation="relu", name="ae_new_bottleneck")(x)
x = layers.Dense(128, activation="relu", name="ae_new_dec1")(x)
output_layer_new = layers.Dense(784, activation="sigmoid", name="ae_new_output")(x)

autoencoder_new = keras.Model(inputs=input_layer_new, outputs=output_layer_new)
autoencoder_new.compile(optimizer="adam", loss="binary_crossentropy")  # same as your AEs

# %%
import numpy as np

def add_gaussian_noise(x, sigma=0.3):
    x_noisy = x + np.random.normal(0.0, sigma, x.shape)
    return np.clip(x_noisy, 0.0, 1.0)

data_clean = np.reshape(fashion_tr.data.cpu().numpy(), (len(fashion_tr.data.cpu().numpy()), 784))
data_noisy = add_gaussian_noise(data_clean, sigma=0.3)

autoencoder_complex.fit(
    data_noisy, data_clean,          # noisy -> clean  (denoising)
    epochs=500,
    batch_size=16,
    verbose=1,
    validation_split=0.25,
    callbacks=[es]
)
# Out:
# Epoch 1/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.2964 - val_loss: 0.2887
# Epoch 2/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2870 - val_loss: 0.2880
# Epoch 3/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2858 - val_loss: 0.2875
# Epoch 4/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2852 - val_loss: 0.2872
# Epoch 5/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2857 - val_loss: 0.2865
# Epoch 6/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2854 - val_loss: 0.2868
# Epoch 7/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2842 - val_loss: 0.2863
# Epoch 8/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2853 - val_loss: 0.2864
# Epoch 9/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.2839 - val_loss: 0.2864
# Epoch 10/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2838 - val_loss: 0.2857
# Epoch 11/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2844 - val_loss: 0.2860
# Epoch 12/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2841 - val_loss: 0.2860
# Epoch 13/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2830 - val_loss: 0.2859
# Epoch 14/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2844 - val_loss: 0.2863
# Epoch 15/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2841 - val_loss: 0.2862
# Epoch 16/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2839 - val_loss: 0.2862
# Epoch 17/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2837 - val_loss: 0.2861
# Epoch 18/500
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.2837 - val_loss: 0.2867
# Epoch 18: early stopping

# %%
# Extract encoders to bottleneck (32-dim output for all AEs)
aesimple_encoder = keras.Model(autoencoder.input, autoencoder.layers[1].output)  # your simple 784->32
aecomplex_encoder = keras.Model(autoencoder_complex.input, autoencoder_complex.layers[2].output)  # 80->32 bottleneck
aenew_encoder = keras.Model(autoencoder_new.input, autoencoder_new.layers[2].output)  # 128->32 bottleneck

# Noisy test data (same sigma=0.3 as training)
data_test_clean = np.reshape(fashion_te.data.cpu().numpy(), (-1, 784))
data_test_noisy = add_gaussian_noise(data_test_clean, sigma=0.3)

# Get 32-dim codes from noisy test data
print("Extracting codes from noisy test data...")
aesimple_codes_noisy_test = aesimple_encoder.predict(data_test_noisy)
aecomplex_codes_noisy_test = aecomplex_encoder.predict(data_test_noisy)
aenew_codes_noisy_test = aenew_encoder.predict(data_test_noisy)

print(f"Shapes: simple={aesimple_codes_noisy_test.shape}, complex={aecomplex_codes_noisy_test.shape}, new={aenew_codes_noisy_test.shape}")
# Out:
# Extracting codes from noisy test data...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Shapes: simple=(10000, 32), complex=(10000, 32), new=(10000, 32)

# %% [markdown]
# ## Linear readout

# %%
class LinearModel(torch.nn.Module):
  def __init__(self, layer_size):
    super().__init__()
    self.linear = torch.nn.Linear(layer_size, 10)

  def forward(self, x):
    return self.linear(x)

# %%
layer_size = dbn_fashion.rbm_layers[0].W.shape[1]
linear1 = LinearModel(layer_size).to(device)

layer_size = dbn_fashion.rbm_layers[1].W.shape[1]
linear2 = LinearModel(layer_size).to(device)

layer_size = dbn_fashion.rbm_layers[2].W.shape[1]
linear3 = LinearModel(layer_size).to(device)

# %%
def train_supervised(network, input_data, epochs=1000):
  optimizer = torch.optim.SGD(network.parameters(), lr=0.05)
  loss_fn = torch.nn.CrossEntropyLoss()

  for epoch in range(epochs):
    optimizer.zero_grad()
    predictions = network(input_data).squeeze()
    targets = fashion_tr.targets.reshape(predictions.shape[0])  # here are the labels
    loss = loss_fn(predictions, targets)
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
      print("epoch : {:3d}/{}, loss = {:.4f}".format(epoch + 1, epochs, loss))

# %%
train_supervised(linear1, hidden_repr_1)
print("---------------------------")
train_supervised(linear2, hidden_repr_2)
print("---------------------------")
train_supervised(linear3, hidden_repr_3)
# Out:
# epoch :   1/1000, loss = 2.3178
# epoch : 101/1000, loss = 0.9211
# epoch : 201/1000, loss = 0.7214
# epoch : 301/1000, loss = 0.6408
# epoch : 401/1000, loss = 0.5943
# epoch : 501/1000, loss = 0.5630
# epoch : 601/1000, loss = 0.5399
# epoch : 701/1000, loss = 0.5220
# epoch : 801/1000, loss = 0.5075
# epoch : 901/1000, loss = 0.4955
# ---------------------------
# epoch :   1/1000, loss = 2.2787
# epoch : 101/1000, loss = 0.7918
# epoch : 201/1000, loss = 0.6457
# epoch : 301/1000, loss = 0.5848
# epoch : 401/1000, loss = 0.5485
# epoch : 501/1000, loss = 0.5235
# epoch : 601/1000, loss = 0.5049
# epoch : 701/1000, loss = 0.4904
# epoch : 801/1000, loss = 0.4786
# epoch : 901/1000, loss = 0.4687
# ---------------------------
# epoch :   1/1000, loss = 2.3123
# epoch : 101/1000, loss = 0.8627
# epoch : 201/1000, loss = 0.6811
# epoch : 301/1000, loss = 0.6082
# epoch : 401/1000, loss = 0.5662
# epoch : 501/1000, loss = 0.5380
# epoch : 601/1000, loss = 0.5174
# epoch : 701/1000, loss = 0.5015
# epoch : 801/1000, loss = 0.4887
# epoch : 901/1000, loss = 0.4782

# %% [markdown]
# Let's now evaluate the trained linear readouts using the hidden representations computed on the *test* set:

# %%
hidden_repr_1_test = get_kth_layer_repr(fashion_te.data, 0, device)
hidden_repr_2_test = get_kth_layer_repr(hidden_repr_1_test, 1, device)
hidden_repr_3_test = get_kth_layer_repr(hidden_repr_2_test, 2, device)

# %% [markdown]
# Compute the classifier predictions:

# %%
predictions_test1 = linear1(hidden_repr_1_test)
predictions_test2 = linear2(hidden_repr_2_test)
predictions_test3 = linear3(hidden_repr_3_test)

# %% [markdown]
# Compute accuracy scores

# %%
def compute_accuracy(predictions_test, targets):
  predictions_indices = predictions_test.max(axis=1).indices  # convert probabilities to indices
  accuracy = (predictions_indices == targets).sum() / len(targets)
  return accuracy.item()

# %%
compute_accuracy(predictions_test1, fashion_te.targets)
# Out:
# 0.8277999758720398

# %%
compute_accuracy(predictions_test2, fashion_te.targets)
# Out:
# 0.8327999711036682

# %%
compute_accuracy(predictions_test3, fashion_te.targets)
# Out:
# 0.8323000073432922

# %%
acc1 = compute_accuracy(predictions_test1, fashion_te.targets)

# %%
# For Layer 1 (repeat for predictionstest2 and predictionstest3)
pred_indices1 = predictions_test1.max(axis=1).indices.cpu()
cm1 = confusion_matrix(fashion_te.targets.cpu(), pred_indices1)
sns.heatmap(cm1, annot=True, fmt='d')
plt.title('Confusion Matrix - Layer 1')
plt.show()

# %% [markdown]
# ## FFNN
# This cell defines a simple linear classifier (LinearModel) as a PyTorch module for supervised readout on DBN hidden representations, then instantiates three models matching the hidden layer sizes (500, 600, 1000 units) from the pretrained RBM stack.
# ​
#
# Training Process
# Each model trains for 1000 epochs using SGD (lr=0.05) and cross-entropy loss on training hidden reps vs. Fashion-MNIST labels, with gradients backpropagated only through the linear layer. Progress prints every 100 epochs, showing loss dropping from ~2.3 to ~0.47-0.49 across layers, indicating convergence.
# ​
#
# Purpose
# This enables evaluation of unsupervised DBN features' discriminability via cheap linear probing, common in representation learning to assess hierarchy depth benefits without full fine-tuning.

# %%
class Feedforward(torch.nn.Module):
  def __init__(self, first_hidden_layer_size, second_hidden_layer_size, third_hidden_layer_size):
    super().__init__()
    self.first_hidden = torch.nn.Linear(784, first_hidden_layer_size)
    self.second_hidden = torch.nn.Linear(first_hidden_layer_size, second_hidden_layer_size)
    self.third_hidden = torch.nn.Linear(second_hidden_layer_size, third_hidden_layer_size)
    self.output = torch.nn.Linear(third_hidden_layer_size, 10)

  def forward(self, input):
    relu = torch.nn.ReLU() #activation function
    first_hidden_repr = relu(self.first_hidden(input))
    second_hidden_repr = relu(self.second_hidden(first_hidden_repr))
    third_hidden_repr = relu(self.third_hidden(second_hidden_repr))
    output = self.output(third_hidden_repr)
    return output

# %%
ffnn = Feedforward(500, 600, 1000).to(device) #feed forward neural network object

# %%
train_supervised(ffnn, fashion_tr.data.reshape((60000, 784)), 1050)
# Out:
# epoch :   1/1050, loss = 2.3023
# epoch : 101/1050, loss = 1.3794
# epoch : 201/1050, loss = 0.8698
# epoch : 301/1050, loss = 0.7419
# epoch : 401/1050, loss = 0.6642
# epoch : 501/1050, loss = 0.6089
# epoch : 601/1050, loss = 0.5718
# epoch : 701/1050, loss = 0.5445
# epoch : 801/1050, loss = 0.5128
# epoch : 901/1050, loss = 0.4997
# epoch : 1001/1050, loss = 0.4825

# %%
predictions_ffnn = ffnn(fashion_te.data.reshape((10000, 784)))

# %%
compute_accuracy(predictions_ffnn, fashion_te.targets)
# Out:
# 0.8168999552726746

# %% [markdown]
# ## Noise

# %% [markdown]
# #EXPERIMENT AE + DBN

# %%
def ae_denoise_torch_batch(x_noisy_torch, autoencoder, device):
    # x_noisy_torch: torch tensor [N,28,28] (or [N,784])
    x = x_noisy_torch.detach().cpu().numpy()
    x = x.reshape(-1, 784).astype("float32")
    x_hat = autoencoder_complex.predict(x, verbose=0)  # [N,784]
    x_hat_torch = torch.tensor(x_hat, device=device).view(-1, 28, 28)
    return x_hat_torch

# %%
def inject_noise(fashion_mnist_data, noise_level):

  ### TASK: create a very simple function that adds some Gaussian noise (see torch.randn function) to the MNIST data
  noise = torch.randn(fashion_te.data.shape, device = device) * noise_level
  noisy_data = fashion_mnist_data + noise
  return noisy_data

# %% [markdown]
# ###EXPERIMENT AE + DBN INSIDE

# %%
def get_accuracy_values_at_noise_level(noise_level):

  fashion_mnist_test_with_noise = inject_noise(fashion_te.data, noise_level)  # first, let's create noisy test images

  ###
  # --- AE -> DBN branch ---
  denoised = ae_denoise_torch_batch(fashion_mnist_test_with_noise, autoencoder, device)

  h1_ae = get_kth_layer_repr(denoised, 0, device)
  h2_ae = get_kth_layer_repr(h1_ae, 1, device)
  h3_ae = get_kth_layer_repr(h2_ae, 2, device)

  pred1_ae = linear1(h1_ae)
  pred2_ae = linear2(h2_ae)
  pred3_ae = linear3(h3_ae)

  acc1_ae = compute_accuracy(pred1_ae, fashion_te.targets)
  acc2_ae = compute_accuracy(pred2_ae, fashion_te.targets)
  acc3_ae = compute_accuracy(pred3_ae, fashion_te.targets)
  ###


  hidden_repr_1_noisy = get_kth_layer_repr(fashion_mnist_test_with_noise, 0, device)  # here we compute the DBN representations
  hidden_repr_2_noisy = get_kth_layer_repr(hidden_repr_1_noisy, 1, device)
  hidden_repr_3_noisy = get_kth_layer_repr(hidden_repr_2_noisy, 2, device)

  predictions_first_hidden_noisy = linear1(hidden_repr_1_noisy)  # here we use the previously-trained read-out classifiers
  predictions_second_hidden_noisy = linear2(hidden_repr_2_noisy)
  predictions_third_hidden_noisy = linear3(hidden_repr_3_noisy)

  accuracy_first_hidden = compute_accuracy(predictions_first_hidden_noisy, fashion_te.targets)
  accuracy_second_hidden = compute_accuracy(predictions_second_hidden_noisy, fashion_te.targets)
  accuracy_third_hidden = compute_accuracy(predictions_third_hidden_noisy, fashion_te.targets)

  ### TASK: repeat a similar process for the feed-forward model (NB: make sure you reshape the input data appropriately!)
  predictions_ffnn_noisy = ffnn(fashion_mnist_test_with_noise.data.reshape((10000, 784)))
  accuracy_ffnn = compute_accuracy(predictions_ffnn_noisy, fashion_te.targets)

  return accuracy_first_hidden, accuracy_second_hidden, accuracy_third_hidden, accuracy_ffnn, acc1_ae, acc2_ae, acc3_ae

# %%
acc = get_accuracy_values_at_noise_level(0.3);
print("Accuracy of H1 read-out: %.3f" % acc[0])
print("Accuracy of H2 read-out: %.3f" % acc[1])
print("Accuracy of H3 read-out: %.3f" % acc[2])
print("Accuracy of FF network : %.3f" % acc[3])
print("Accuracy of AE+DBN network : %.3f" % acc[4])
print("Accuracy of AE+DBN network : %.3f" % acc[5])
print("Accuracy of AE+DBN network : %.3f" % acc[6])
# Out:
# Accuracy of H1 read-out: 0.799
# Accuracy of H2 read-out: 0.814
# Accuracy of H3 read-out: 0.813
# Accuracy of FF network : 0.784
# Accuracy of AE+DBN network : 0.763
# Accuracy of AE+DBN network : 0.763
# Accuracy of AE+DBN network : 0.768

# %%
def plot_noise_robustness_curves(noise_levels):
  accuracy_values_first_hidden = []
  accuracy_values_second_hidden = []
  accuracy_values_third_hidden = []
  accuracy_values_ffnn = []

  for noise_level in noise_levels:
    acc = get_accuracy_values_at_noise_level(noise_level)
    accuracy_values_first_hidden.append(acc[0])
    accuracy_values_second_hidden.append(acc[1])
    accuracy_values_third_hidden.append(acc[2])
    accuracy_values_ffnn.append(acc[3])

  fig, ax = plt.subplots()
  ax.plot(range(len(noise_levels)), accuracy_values_first_hidden)
  ax.plot(range(len(noise_levels)), accuracy_values_second_hidden)
  ax.plot(range(len(noise_levels)), accuracy_values_third_hidden)
  ax.plot(range(len(noise_levels)), accuracy_values_ffnn)

  ax.set_title("Robustness to noise")
  ax.set_xlabel("Noise level (%)")
  ax.set_ylabel("Accuracy")
  plt.xticks(range(len(noise_levels)), [int(l*100) for l in noise_levels])
  plt.legend(["First hidden", "Second hidden", "Third hidden", "FFNN"])

# %%
noise_levels = np.linspace(0,2,10)
plot_noise_robustness_curves(noise_levels)

# %% [markdown]
# ##Adversarial Attacks

# %%
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()

    ### Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad


    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, 0, 1)

    # Return the perturbed image
    return perturbed_image

# %%
class DBNWithReadOut(torch.nn.Module):
    def __init__(self, dbn_fashion_mnist, readout):
        super().__init__()
        self.readout = readout
        self.readout_level = 2
        self.dbn_fashion_mnist = dbn_fashion_mnist
        self._require_grad()

    def _require_grad(self):
      for rbm in self.dbn_fashion_mnist.rbm_layers:
        rbm.W.requires_grad_()
        rbm.h_bias.requires_grad_()

    def forward(self, image):
      """This forward pass uses probabilities instead of samples as RBM activations
       to backpropagate the gradient"""
      p_v = image
      hidden_states = []
      for rbm in self.dbn_fashion_mnist.rbm_layers:
        p_v = p_v.view((p_v.shape[0], -1))  # flatten
        p_v, v = rbm(p_v)
        hidden_states.append(p_v)
      return self.readout.forward(hidden_states[self.readout_level])

# %%
dbn_with_readout = DBNWithReadOut(dbn_fashion, linear3)

# %%
test_sample_idx = 101
test_image = fashion_te.data[test_sample_idx].reshape(1, 784)
__ = plt.imshow(test_image.reshape(28,28).to('cpu'), cmap = 'gray')

# %% [markdown]
# Try to classify this image with one of models used before (DBN/FFNN)

# %%
attacked_model = dbn_with_readout

# %%
test_image.requires_grad_()
model_outputs = attacked_model(test_image)
prediction = torch.argmax(model_outputs)
print(f"The prediction of the model for this clean sample is {class_names[prediction.item()]}.")
# Out:
# The prediction of the model for this clean sample is Shirt.

# %%
epsilon = 0.25  # define strength of the attack
test_image_label = fashion_te.targets[test_sample_idx].unsqueeze(0)  # get ground truth label for that image
loss_value = torch.nn.functional.cross_entropy(model_outputs, test_image_label)  # get loss value
attacked_model.zero_grad()
loss_value.backward(retain_graph=True)
image_grad = test_image.grad.data  # get the gradient of the pixels w.r.t. the loss

### Note: before plotting you'll probably need to send the data back to the cpu
perturbed_image = fgsm_attack(test_image, epsilon, image_grad)
perturbed_image_np = perturbed_image.detach().to('cpu').numpy()
__ = plt.imshow(perturbed_image_np.reshape(28,28), cmap = 'gray')

# %%
model_outputs = attacked_model(perturbed_image.view((perturbed_image.shape[0], -1)))
prediction = torch.argmax(model_outputs)
print(f"The prediction of the model for this clean sample is {class_names[prediction.item()]}.")
# Out:
# The prediction of the model for this clean sample is Coat.

# %% [markdown]
# ##Resisting to adversarial attacks

# %%
def test_robustness_to_attack(model, device, test_loader, epsilon, num_steps=0, verbose=True):
    correct = 0  # count number of correct classifications
    print_reconstruction = num_steps > 0  # if we request for top-down reconstruction, show the resulting image

    for data, target in tqdm(test_loader):
        data, target = data.to(device), target.to(device)
        data = data.reshape(-1, 784)
        data.requires_grad = True  # we need to get the gradient to perform the attack

        output = model.forward(data)  # forward pass through the model

        init_pred = torch.argmax(output)  # prediction before the attack

        if (print_reconstruction and verbose):
          print("\nHere's the original sample:\n")
          plt.imshow(data[0].detach().to('cpu').numpy().reshape(28,28))
          plt.show()

        loss_value = torch.nn.functional.cross_entropy(output, target) # get loss value
        model.zero_grad()
        loss_value.backward()
        data_grad = data.grad.data  # collect the gradient with respect to the input data
        perturbed_data = fgsm_attack(data, epsilon, data_grad)  # call the attack function previously defined

        if (print_reconstruction and verbose):
            print("\nHere's a perturbed sample:\n")
            plt.imshow(perturbed_data[0].detach().to('cpu').numpy().reshape(28,28))
            plt.show()

        # If requested, reconstruct the input iterating bottom-up and top-down sampling
        if num_steps > 0:
            for __ in range(0, num_steps):
                perturbed_data, __ = model.dbn_fashion_mnist.reconstruct(perturbed_data)
            if (print_reconstruction and verbose):
                print(f"\nHere's what a {num_steps}-steps reconstructed sample looks like:\n")
                plt.imshow(perturbed_data[0].detach().to('cpu').numpy().reshape(28,28))
                plt.show()
                print_reconstruction = False

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        # get the index of the max element in the output
        final_pred = output.max(1, keepdim=True)[1]
        final_pred = output.argmax(-1)
        correct += (final_pred == target).sum()

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader.sampler))
    print("\nEpsilon: {}\nTest Accuracy: {:.2f}%\n".format(epsilon, final_acc*100))

    return final_acc.item()

# %%
test_loader = torch.utils.data.DataLoader(
    tv.datasets.FashionMNIST('data/', train=False, download=True, transform=tv.transforms.Compose([tv.transforms.ToTensor()])),
    batch_size=100, shuffle=True)
# Out:
# 100%|██████████| 26.4M/26.4M [00:00<00:00, 113MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 3.98MB/s]
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 63.7MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 33.4MB/s]

# %%
final_acc = test_robustness_to_attack(ffnn, device,
                                      test_loader, epsilon=0.2,
                                      num_steps=0)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.2
# Test Accuracy: 0.38%

# %%
final_acc = test_robustness_to_attack(dbn_with_readout, device,
                                      test_loader, epsilon=0.2,
                                      num_steps=0)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.2
# Test Accuracy: 13.35%

# %% [markdown]
# ### We add two top-down reconstruction steps

# %%
### TASK: repeat the same test for the DBN with 2 top-down reconstruction steps
final_acc = test_robustness_to_attack(dbn_with_readout, device,
                                      test_loader, epsilon=0.2,
                                      num_steps=2)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Here's the original sample:
# Here's a perturbed sample:
# Here's what a 2-steps reconstructed sample looks like:
# Epsilon: 0.2
# Test Accuracy: 13.88%

# %%
epsilon_values = [0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]

def test_epsilon_values_effect(model, n_steps):
  accuracies = list()

  for eps in epsilon_values:
      acc = test_robustness_to_attack(model, device, test_loader, eps, num_steps=n_steps, verbose=False)  # set verbose to False to avoid displaying too many images
      accuracies.append(acc)

  return accuracies

# %%
# %%capture
accuracies_ffnn = test_epsilon_values_effect(ffnn, n_steps=0)
accuracies_dbn_0 = test_epsilon_values_effect(dbn_with_readout, n_steps=0)
accuracies_dbn_1 = test_epsilon_values_effect(dbn_with_readout, n_steps=2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 7), sharey=True)

__ = ax.axhline(0.1, color='gray', linestyle=':')
__ = ax.plot(epsilon_values, accuracies_ffnn)
__ = ax.plot(epsilon_values, accuracies_dbn_0)
__ = ax.plot(epsilon_values, accuracies_dbn_1)
__ = ax.set_xlabel(r"Strength of adversarial attack ($\epsilon$)")
__ = ax.set_ylabel("Accuracy")
__ = ax.set_title("Robustness to adversarial attacks", {'fontsize': 15})
__ = ax.legend(["Chance level", "FFNN", "DBN", "DBN top-down"])

# %% [markdown]
# #Second AE section (to refine)

# %%
# Cell 5: FIXED Complex Encoder (32-dim bottleneck)
ae_simple_encoder = keras.Model(inputs=autoencoder.input, outputs=autoencoder.layers[1].output)

# FIXED: Point to L2 (32-dim), not L1 (80-dim)
bottleneck_layer = autoencoder_complex.layers[2]  # Dense32 after Dense80
ae_complex_encoder = keras.Model(inputs=autoencoder_complex.input, outputs=bottleneck_layer.output)

print(f"Simple encoder: {ae_simple_encoder.output_shape}")   # (None, 32)
print(f"Complex encoder: {ae_complex_encoder.output_shape}")  # (None, 32)
# Out:
# Simple encoder: (None, 32)
# Complex encoder: (None, 32)

# %%
class LinearProbe(torch.nn.Module):
    def __init__(self, input_dim=32):
        super().__init__()
        self.linear = torch.nn.Linear(input_dim, 10)

    def forward(self, x):
        return torch.nn.functional.log_softmax(self.linear(x), dim=-1)

ae_simple_probe = LinearProbe().to(device)
ae_complex_probe = LinearProbe().to(device)

# %%
# Extract clean training codes for all 3 AEs (32-dim)
import torch.nn.functional as F
data_train_clean = np.reshape(fashion_tr.data.cpu().numpy(), (-1, 784))
aesimple_codes_train_clean = aesimple_encoder.predict(data_train_clean)
aecomplex_codes_train_clean = aecomplex_encoder.predict(data_train_clean)
aenew_codes_train_clean = aenew_encoder.predict(data_train_clean)

# Convert to PyTorch tensors (GPU)
aesimple_codes_train_torch = torch.tensor(aesimple_codes_train_clean).to(device)
aecomplex_codes_train_torch = torch.tensor(aecomplex_codes_train_clean).to(device)
aenew_codes_train_torch = torch.tensor(aenew_codes_train_clean).to(device)

# Noisy test codes (already have)
aesimple_codes_noisy_test_torch = torch.tensor(aesimple_codes_noisy_test).to(device)
aecomplex_codes_noisy_test_torch = torch.tensor(aecomplex_codes_noisy_test).to(device)
aenew_codes_noisy_test_torch = torch.tensor(aenew_codes_noisy_test).to(device)

# Denoising probes (32 -> 10)
aesimple_denoise_probe = LinearProbe(32).to(device)
aecomplex_denoise_probe = LinearProbe(32).to(device)
aenew_denoise_probe = LinearProbe(32).to(device)

def evaluate_probe(model, test_codes):
    model.eval()
    with torch.no_grad():
        logits = model(test_codes)
        probs = F.softmax(logits, dim=1)
        preds = torch.argmax(probs, dim=1)
        targets = fashion_te.targets.cpu() # Corrected: targets are already 1D class labels
        acc = (preds.cpu() == targets).float().mean().item()
    return acc

# Finish probe training + eval
print("simple:", evaluate_probe(aesimple_denoise_probe, aesimple_codes_noisy_test_torch))
print("---")
train_supervised(aecomplex_denoise_probe, aecomplex_codes_train_torch)
print("complex:", evaluate_probe(aecomplex_denoise_probe, aecomplex_codes_noisy_test_torch))
print("---")
train_supervised(aenew_denoise_probe, aenew_codes_train_torch)
print("new:", evaluate_probe(aenew_denoise_probe, aenew_codes_noisy_test_torch))
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# simple: 0.08349999785423279
# ---
# epoch :   1/1000, loss = 3.9126
# epoch : 101/1000, loss = 0.6557
# epoch : 201/1000, loss = 0.5861
# epoch : 301/1000, loss = 0.5572
# epoch : 401/1000, loss = 0.5406
# epoch : 501/1000, loss = 0.5296
# epoch : 601/1000, loss = 0.5216
# epoch : 701/1000, loss = 0.5156
# epoch : 801/1000, loss = 0.5109
# epoch : 901/1000, loss = 0.5070
# complex: 0.7355999946594238
# ---
# epoch :   1/1000, loss = 2.3378
# epoch : 101/1000, loss = 2.1594
# epoch : 201/1000, loss = 2.0303
# epoch : 301/1000, loss = 1.9219
# epoch : 401/1000, loss = 1.8302
# epoch : 501/1000, loss = 1.7523
# epoch : 601/1000, loss = 1.6855
# epoch : 701/1000, loss = 1.6279
# epoch : 801/1000, loss = 1.5779
# epoch : 901/1000, loss = 1.5341
# new: 0.4212000072002411

# %%
# Train on CLEAN Fashion-MNIST AE codes
train_data_np = np.reshape(fashion_tr.data.cpu().numpy(), (len(fashion_tr.data.cpu().numpy()), 784)) # (60k, 784)
train_s_codes = torch.tensor(ae_simple_encoder.predict(train_data_np, verbose=0)).to(device)
train_c_codes = torch.tensor(ae_complex_encoder.predict(train_data_np, verbose=0)).to(device)

train_supervised(ae_simple_probe, train_s_codes)
train_supervised(ae_complex_probe, train_c_codes)
print("✅ AE probes trained!")
# Out:
# epoch :   1/1000, loss = 2.9668
# epoch : 101/1000, loss = 0.6659
# epoch : 201/1000, loss = 0.5983
# epoch : 301/1000, loss = 0.5701
# epoch : 401/1000, loss = 0.5537
# epoch : 501/1000, loss = 0.5428
# epoch : 601/1000, loss = 0.5348
# epoch : 701/1000, loss = 0.5288
# epoch : 801/1000, loss = 0.5240
# epoch : 901/1000, loss = 0.5200
# epoch :   1/1000, loss = 3.0236
# epoch : 101/1000, loss = 0.6540
# epoch : 201/1000, loss = 0.5871
# epoch : 301/1000, loss = 0.5576
# epoch : 401/1000, loss = 0.5404
# epoch : 501/1000, loss = 0.5291
# epoch : 601/1000, loss = 0.5210
# epoch : 701/1000, loss = 0.5149
# epoch : 801/1000, loss = 0.5101
# epoch : 901/1000, loss = 0.5063
# ✅ AE probes trained!
